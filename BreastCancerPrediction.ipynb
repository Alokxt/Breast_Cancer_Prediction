# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns 
from sklearn.model_selection import train_test_split 
from sklearn.metrics import classification_report

# %%
df = pd.read_csv('breast-cancer.csv')

# %%
df.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
df['diagnosis'].value_counts()
# Out:
# diagnosis
# B    357
# M    212
# Name: count, dtype: int64

# %% [markdown]
# B = benign tumor , M = Malignant tumor

# %% [markdown]
# Let's Analysis the data first

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 32 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       569 non-null    int64
#  1   diagnosis                569 non-null    object
#  2   radius_mean              569 non-null    float64
#  3   texture_mean             569 non-null    float64
#  4   perimeter_mean           569 non-null    float64
#  5   area_mean                569 non-null    float64
#  6   smoothness_mean          569 non-null    float64
#  7   compactness_mean         569 non-null    float64
#  8   concavity_mean           569 non-null    float64
#  9   concave points_mean      569 non-null    float64
#  10  symmetry_mean            569 non-null    float64
#  11  fractal_dimension_mean   569 non-null    float64
#  12  radius_se                569 non-null    float64
#  13  texture_se               569 non-null    float64
# ...

# %%
df.describe()
# Out:
#                  id  radius_mean  texture_mean  perimeter_mean    area_mean  \
# count  5.690000e+02   569.000000    569.000000      569.000000   569.000000
# mean   3.037183e+07    14.127292     19.289649       91.969033   654.889104
# std    1.250206e+08     3.524049      4.301036       24.298981   351.914129
# min    8.670000e+03     6.981000      9.710000       43.790000   143.500000
# 25%    8.692180e+05    11.700000     16.170000       75.170000   420.300000
# 50%    9.060240e+05    13.370000     18.840000       86.240000   551.100000
# 75%    8.813129e+06    15.780000     21.800000      104.100000   782.700000
# max    9.113205e+08    28.110000     39.280000      188.500000  2501.000000
#
#        smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# count       569.000000        569.000000      569.000000           569.000000
# mean          0.096360          0.104341        0.088799             0.048919
# ...

# %%
df.columns
# Out:
# Index(['id', 'diagnosis', 'radius_mean', 'texture_mean', 'perimeter_mean',
#        'area_mean', 'smoothness_mean', 'compactness_mean', 'concavity_mean',
#        'concave points_mean', 'symmetry_mean', 'fractal_dimension_mean',
#        'radius_se', 'texture_se', 'perimeter_se', 'area_se', 'smoothness_se',
#        'compactness_se', 'concavity_se', 'concave points_se', 'symmetry_se',
#        'fractal_dimension_se', 'radius_worst', 'texture_worst',
#        'perimeter_worst', 'area_worst', 'smoothness_worst',
#        'compactness_worst', 'concavity_worst', 'concave points_worst',
#        'symmetry_worst', 'fractal_dimension_worst'],
#       dtype='object')

# %%
df[df.columns].describe().T
# Out:
#                          count          mean           std          min  \
# id                       569.0  3.037183e+07  1.250206e+08  8670.000000
# radius_mean              569.0  1.412729e+01  3.524049e+00     6.981000
# texture_mean             569.0  1.928965e+01  4.301036e+00     9.710000
# perimeter_mean           569.0  9.196903e+01  2.429898e+01    43.790000
# area_mean                569.0  6.548891e+02  3.519141e+02   143.500000
# smoothness_mean          569.0  9.636028e-02  1.406413e-02     0.052630
# compactness_mean         569.0  1.043410e-01  5.281276e-02     0.019380
# concavity_mean           569.0  8.879932e-02  7.971981e-02     0.000000
# concave points_mean      569.0  4.891915e-02  3.880284e-02     0.000000
# symmetry_mean            569.0  1.811619e-01  2.741428e-02     0.106000
# fractal_dimension_mean   569.0  6.279761e-02  7.060363e-03     0.049960
# radius_se                569.0  4.051721e-01  2.773127e-01     0.111500
# ...

# %%
plt.figure(figsize=(8,6))
sns.countplot(x='diagnosis',data=df)
plt.show()

# %% [markdown]
# #Too many features , lets take a look at which features contribute most to the malignant tumor

# %%
df['symmetry_worst'][df['diagnosis'] == 'M']
# Out:
# 0      0.4601
# 1      0.2750
# 2      0.3613
# 3      0.6638
# 4      0.2364
#         ...
# 563    0.2929
# 564    0.2060
# 565    0.2572
# 566    0.2218
# 567    0.4087
# Name: symmetry_worst, Length: 212, dtype: float64

# %% [markdown]
# Let's do a kruskal-wallis test to test the significance of each column

# %%
from spicy import stats

# %%
def kruskal_wallis(df):
    column_to_test = list(df.select_dtypes('float64').columns)
    useless_cols = []
    for i in column_to_test:
        mels = df[i][df['diagnosis'] == 'M']
        ben = df[i][df['diagnosis'] == 'B']

        stat_val , p_value = stats.kruskal(mels,ben)
        if p_value >=0.05:
            print(p_value,i)
            useless_cols.append(i)
    return useless_cols

# %%
l = kruskal_wallis(df)
# Out:
# 0.5370116855805784 fractal_dimension_mean
# 0.6435036506453742 texture_se
# 0.21353455073715374 smoothness_se

# %%
new_df = df.drop(columns=l)

# %%
new_df
# Out:
#            id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0      842302         M        17.99         10.38          122.80     1001.0
# 1      842517         M        20.57         17.77          132.90     1326.0
# 2    84300903         M        19.69         21.25          130.00     1203.0
# 3    84348301         M        11.42         20.38           77.58      386.1
# 4    84358402         M        20.29         14.34          135.10     1297.0
# ..        ...       ...          ...           ...             ...        ...
# 564    926424         M        21.56         22.39          142.00     1479.0
# 565    926682         M        20.13         28.25          131.20     1261.0
# 566    926954         M        16.60         28.08          108.30      858.1
# 567    927241         M        20.60         29.33          140.10     1265.0
# 568     92751         B         7.76         24.54           47.92      181.0
#
# ...

# %%
cols = list(df.columns)

cols.remove('id')
cols.remove('diagnosis')
print(cols)
# Out:
# ['radius_mean', 'texture_mean', 'perimeter_mean', 'area_mean', 'smoothness_mean', 'compactness_mean', 'concavity_mean', 'concave points_mean', 'symmetry_mean', 'fractal_dimension_mean', 'radius_se', 'texture_se', 'perimeter_se', 'area_se', 'smoothness_se', 'compactness_se', 'concavity_se', 'concave points_se', 'symmetry_se', 'fractal_dimension_se', 'radius_worst', 'texture_worst', 'perimeter_worst', 'area_worst', 'smoothness_worst', 'compactness_worst', 'concavity_worst', 'concave points_worst', 'symmetry_worst', 'fractal_dimension_worst']

# %%
c = 0

for i in cols:
    c += 1
    g1 = df[i][df['diagnosis']=='M']
    g2 = df[i][df['diagnosis']=='B']
   
    plt.figure(figsize=(6,4))
    ax = sns.barplot(x=df['diagnosis'], y=df[i], hue=df['diagnosis'], dodge=False)
    ax.bar_label(ax.containers[0])
    ax.bar_label(ax.containers[1]) 
    plt.xticks(ticks=[0,1], labels=['benign', 'malignant'])
    plt.title(f'Avg {i} Values by Target Class', fontsize=18)
    plt.show()
    if(c == 20):
        break

# %%
df['radius_mean'][df['diagnosis']=='M'].describe()
# Out:
# count    212.000000
# mean      17.462830
# std        3.203971
# min       10.950000
# 25%       15.075000
# 50%       17.325000
# 75%       19.590000
# max       28.110000
# Name: radius_mean, dtype: float64

# %%
new_df['diagnosis'] = new_df['diagnosis'].apply(lambda x: 0 if x == 'B' else 1)

# %%
new_df.sample(5)
# Out:
#          id  diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 48   857155          0       12.050         14.63           78.04      449.3
# 424  907145          0        9.742         19.12           61.93      289.7
# 229  881861          1       12.830         22.33           85.26      503.2
# 489  913535          1       16.690         20.20          107.10      857.6
# 439  909410          0       14.020         15.66           89.59      606.5
#
#      smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 48           0.10310           0.09092        0.065920              0.02749
# 424          0.10750           0.08333        0.008934              0.01967
# 229          0.10880           0.17990        0.169500              0.06861
# 489          0.07497           0.07112        0.036490              0.02307
# 439          0.07966           0.05581        0.020870              0.02652
#
# ...

# %%
X1 = new_df.drop(columns=['diagnosis','id'])
Y = new_df['diagnosis']
X = X1.to_numpy()

# %%
X
# Out:
# array([[1.799e+01, 1.038e+01, 1.228e+02, ..., 2.654e-01, 4.601e-01,
#         1.189e-01],
#        [2.057e+01, 1.777e+01, 1.329e+02, ..., 1.860e-01, 2.750e-01,
#         8.902e-02],
#        [1.969e+01, 2.125e+01, 1.300e+02, ..., 2.430e-01, 3.613e-01,
#         8.758e-02],
#        ...,
#        [1.660e+01, 2.808e+01, 1.083e+02, ..., 1.418e-01, 2.218e-01,
#         7.820e-02],
#        [2.060e+01, 2.933e+01, 1.401e+02, ..., 2.650e-01, 4.087e-01,
#         1.240e-01],
#        [7.760e+00, 2.454e+01, 4.792e+01, ..., 0.000e+00, 2.871e-01,
#         7.039e-02]])

# %%
from sklearn.preprocessing import StandardScaler

# %%
sc = StandardScaler()

# %%
sc.fit(X)
# Out:
# StandardScaler()

# %%
X_centred = sc.transform(X)

# %%
X_centred
# Out:
# array([[ 1.09706398, -2.07333501,  1.26993369, ...,  2.29607613,
#          2.75062224,  1.93701461],
#        [ 1.82982061, -0.35363241,  1.68595471, ...,  1.0870843 ,
#         -0.24388967,  0.28118999],
#        [ 1.57988811,  0.45618695,  1.56650313, ...,  1.95500035,
#          1.152255  ,  0.20139121],
#        ...,
#        [ 0.70228425,  2.0455738 ,  0.67267578, ...,  0.41406869,
#         -1.10454895, -0.31840916],
#        [ 1.83834103,  2.33645719,  1.98252415, ...,  2.28998549,
#          1.91908301,  2.21963528],
#        [-1.80840125,  1.22179204, -1.81438851, ..., -1.74506282,
#         -0.04813821, -0.75120669]])

# %%
l = list(new_df.columns)

# %%
l.remove('diagnosis')
l.remove('id')

# %%
k = new_df.copy()
k.drop(columns=['diagnosis','id'],inplace=True)

# %%
k.head()
# Out:
#    radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    compactness_mean  concavity_mean  concave points_mean  symmetry_mean  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4           0.13280          0.1980              0.10430         0.1809
#
#    radius_se  ...  radius_worst  texture_worst  perimeter_worst  area_worst  \
# ...

# %%
k[l] = X_centred

# %%
k.head()
# Out:
#    radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 0     1.097064     -2.073335        1.269934   0.984375         1.568466
# 1     1.829821     -0.353632        1.685955   1.908708        -0.826962
# 2     1.579888      0.456187        1.566503   1.558884         0.942210
# 3    -0.768909      0.253732       -0.592687  -0.764464         3.283553
# 4     1.750297     -1.151816        1.776573   1.826229         0.280372
#
#    compactness_mean  concavity_mean  concave points_mean  symmetry_mean  \
# 0          3.283515        2.652874             2.532475       2.217515
# 1         -0.487072       -0.023846             0.548144       0.001392
# 2          1.052926        1.363478             2.037231       0.939685
# 3          3.402909        1.915897             1.451707       2.867383
# 4          0.539340        1.371011             1.428493      -0.009560
#
#    radius_se  ...  radius_worst  texture_worst  perimeter_worst  area_worst  \
# ...

# %%
cov_mat = np.cov(X_centred.T)

# %%
eigen_values, eigen_vectors = np.linalg.eig(cov_mat)

# %%
eigen_values.shape
# Out:
# (27,)

# %%
eigen_vectors.shape
# Out:
# (27, 27)

# %%
total = np.sum(eigen_values)
print(total)
# Out:
# 27.04753521126762

# %%
eigen_values_ratio = (eigen_values / total)*100
print(eigen_values_ratio)
# Out:
# [4.89913861e+01 1.75488394e+01 8.81839014e+00 6.52421695e+00
#  5.24276590e+00 3.59082824e+00 2.19015359e+00 1.38746410e+00
#  1.32693286e+00 1.07304980e+00 9.16343818e-01 5.45575754e-01
#  3.42125388e-01 2.89371312e-01 2.28347129e-01 2.12044628e-01
#  1.81118137e-01 1.71019774e-01 1.17081516e-01 9.22063694e-02
#  7.75692610e-02 6.34602456e-02 5.02206326e-04 2.85209881e-03
#  6.00273961e-03 3.33326193e-02 2.70198837e-02]

# %%
explained_var =[]
c = 0
for i , var in enumerate(eigen_values_ratio):
    c += round(var,3)
    if c<92:
          explained_var.append(var)
          print(f'At {i+1} PC, Explained Variance is {round(c,2)}%')
    else:
        explained_var.append(var)
        print(f'At {i+1} PC, Explained Variance crosses threshold: {round(c,2)}%')
        break
# Out:
# At 1 PC, Explained Variance is 48.99%
# At 2 PC, Explained Variance is 66.54%
# At 3 PC, Explained Variance is 75.36%
# At 4 PC, Explained Variance is 81.88%
# At 5 PC, Explained Variance is 87.12%
# At 6 PC, Explained Variance is 90.72%
# At 7 PC, Explained Variance crosses threshold: 92.91%

# %% [markdown]
# So we have to take 8 principle components

# %%
explained_variance_ratio = eigen_values / np.sum(eigen_values) * 100
cumulative_variance = np.cumsum(explained_variance_ratio)

plt.figure(figsize=(8,5))
plt.plot(range(1, len(cumulative_variance)+1), cumulative_variance, marker='o', linestyle='--', color='b')
plt.xlabel('Number of Principal Components')
plt.ylabel('Cumulative Explained Variance (%)')
plt.title('Explained Variance vs Number of Components')
plt.grid(True)
plt.show()

# %%
print(explained_var)
# Out:
# [48.991386118488414, 17.548839420824095, 8.818390139734467, 6.524216952414987, 5.242765895617344, 3.590828244248577, 2.1901535892256176]

# %%
print(np.sum(explained_var))
# Out:
# 92.90658036055348

# %%
PCs = eigen_vectors[0:len(explained_var)]

# %%
PCs
# Out:
# array([[-0.22362118,  0.24091559, -0.02150782,  0.02051057, -0.08154766,
#          0.13461283,  0.10410693,  0.18749858,  0.05899256,  0.09310178,
#          0.02356494,  0.06073827, -0.07598771, -0.14458281,  0.2146644 ,
#          0.11634892, -0.18344918,  0.2253482 ,  0.01082114,  0.07602509,
#          0.0909918 , -0.12069767,  0.70474921,  0.20610279,  0.21581778,
#         -0.12637317,  0.05234118],
#        [-0.10461972,  0.0668149 , -0.13374125, -0.54785905,  0.36700727,
#         -0.16884659,  0.12713548,  0.08036379,  0.08496882, -0.057005  ,
#          0.07824179, -0.05145791, -0.05976433, -0.25635057,  0.33101554,
#         -0.38767656,  0.35081317, -0.01232132, -0.02555928,  0.01494054,
#         -0.08228211,  0.02950664,  0.00084551, -0.00288081,  0.00653709,
#         -0.02284166,  0.00505239],
#        [-0.23191501,  0.22053373, -0.0192858 ,  0.02170306, -0.07990383,
#          0.1264334 ,  0.09699808,  0.19249775,  0.06012524,  0.05662201,
# ...

# %%
PCs.shape
# Out:
# (7, 27)

# %%
PCs.T[0]
# Out:
# array([-0.22362118, -0.10461972, -0.23191501, -0.22548221, -0.1390669 ,
#        -0.23688907, -0.25780073])

# %%
idx = np.argsort(eigen_values)[::-1]
sort_values = eigen_values[idx]
sorted_eigenvectors = eigen_vectors[:, idx]
eigen_value_ratio2 = sort_values / total * 100

# %%
explained_var2 = []
c = 0
for i,var in enumerate(eigen_value_ratio2):
    c += round(var,3)
    explained_var2.append(var)
    if c>92 :
        break 
print(explained_var2)
# Out:
# [48.991386118488414, 17.548839420824095, 8.818390139734467, 6.524216952414987, 5.242765895617344, 3.590828244248577, 2.1901535892256176]

# %%
print(np.sum(explained_var))
# Out:
# 92.90658036055348

# %%
new_PC = sorted_eigenvectors[:,:len(explained_var)]

# %%
new_PC
# Out:
# array([[-0.22362118,  0.24091559, -0.02150782,  0.02051057, -0.08154766,
#          0.13461283,  0.10410693],
#        [-0.10461972,  0.0668149 , -0.13374125, -0.54785905,  0.36700727,
#         -0.16884659,  0.12713548],
#        [-0.23191501,  0.22053373, -0.0192858 ,  0.02170306, -0.07990383,
#          0.1264334 ,  0.09699808],
#        [-0.22548221,  0.2445292 ,  0.01184728,  0.03248952, -0.05275024,
#          0.08713074,  0.03433832],
#        [-0.1390669 , -0.19746086, -0.12416025,  0.3475613 ,  0.07642762,
#         -0.45607195,  0.25249674],
#        [-0.23688907, -0.17910667, -0.03636325,  0.04410548, -0.04514258,
#         -0.02419607, -0.01899849],
#        [-0.25780073, -0.07896451,  0.03416361, -0.01976422, -0.08336212,
#          0.02002911,  0.10855017],
#        [-0.26185256,  0.0274153 , -0.02463639,  0.09071923, -0.04369864,
#         -0.02702719,  0.17927914],
#        [-0.1351207 , -0.2184982 , -0.02370533,  0.23926764,  0.3536079 ,
# ...

# %%
new_PC.shape
# Out:
# (27, 7)

# %%
X_centred.shape
# Out:
# (569, 27)

# %%
X_pca = X_centred.dot(new_PC)

# %%
X_pca.shape
# Out:
# (569, 7)

# %%
label, counts = np.unique(Y, return_counts=True)
# compute the class weights
counts = max(counts) / counts
class_weights = dict(zip(label, np.around(counts,3)))
print('=== CLASS WEIGHTS ===')
print(class_weights)
# Out:
# === CLASS WEIGHTS ===
# {0: 1.0, 1: 1.684}

# %%
Y1 = Y.to_numpy()

# %%
X_train,X_test,Y_train,Y_test = train_test_split(X_pca,Y1,test_size=0.2,random_state=42)

# %%
X_train.shape
# Out:
# (455, 7)

# %%
Y_test.shape
# Out:
# (114,)

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier

from sklearn.linear_model import LogisticRegression

# %%
knn = KNeighborsClassifier(n_neighbors=5,weights='distance')
svm = SVC(kernel="linear", C=0.025, class_weight=class_weights, random_state=42)
rnd = RandomForestClassifier(max_depth=5, n_estimators=100, class_weight=class_weights, random_state=42)
rlg = LogisticRegression

# %%
knn.fit(X_train,Y_train)
# Out:
# KNeighborsClassifier(weights='distance')

# %%
preds1 = knn.predict(X_test)

# %%
print(classification_report(preds1,Y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.96      0.97        72
#            1       0.93      0.95      0.94        42
#
#     accuracy                           0.96       114
#    macro avg       0.95      0.96      0.95       114
# weighted avg       0.96      0.96      0.96       114

# %% [markdown]
# Knn performs really well, with an recall value of .95 and accuracy of 96 . Let's try SVM

# %%
svm.fit(X_train,Y_train)
# Out:
# SVC(C=0.025, class_weight={0: 1.0, 1: 1.684}, kernel='linear', random_state=42)

# %%
preds2 = svm.predict(X_test)

# %%
print(classification_report(preds2,Y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98        70
#            1       0.98      0.95      0.97        44
#
#     accuracy                           0.97       114
#    macro avg       0.97      0.97      0.97       114
# weighted avg       0.97      0.97      0.97       114

# %% [markdown]
# SVM surpasses KNN with an acuuracy of 97 and recall of 0.95 , Let's try Random forest

# %%
rnd.fit(X_train,Y_train)
# Out:
# RandomForestClassifier(class_weight={0: 1.0, 1: 1.684}, max_depth=5,
#                        random_state=42)

# %%
preds3 = rnd.predict(X_test)

# %%
print(classification_report(preds3,Y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      0.97      0.96        70
#            1       0.95      0.93      0.94        44
#
#     accuracy                           0.96       114
#    macro avg       0.96      0.95      0.95       114
# weighted avg       0.96      0.96      0.96       114

# %% [markdown]
# Random Forest gives the accuracy as KNN but has low recall value and f1_score

# %% [markdown]
# So , SVC is our final algorithm to predict the tumor in women's breast.

# %%
def Breast_Cancer_prediction(data):
    x = np.array(data).reshape(1,-1)
    
    X_cen = sc.transform(x)
    x_pca = X_cen.dot(new_PC)
    prediction = svm.predict(x_pca)
    return prediction

# %%
new_df.head()
# Out:
#          id  diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302          1        17.99         10.38          122.80     1001.0
# 1    842517          1        20.57         17.77          132.90     1326.0
# 2  84300903          1        19.69         21.25          130.00     1203.0
# 3  84348301          1        11.42         20.38           77.58      386.1
# 4  84358402          1        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
l = new_df.drop(columns=['diagnosis','id']).iloc[400]

# %%
len(list(l))
# Out:
# 27

# %%
Breast_Cancer_prediction(list(l))
# Out:
# array([1], dtype=int64)

# %%
print(np.__version__)
print(pd.__version__)
# Out:
# 1.26.4
# 2.2.1

# %%
import pickle

# %%
pickle.dump(svm,open('model1.pkl','wb'))

# %%
import sklearn

# %%
sklearn.__version__
# Out:
# '1.5.1'

# %%
pickle.dump(Breast_Cancer_prediction,open('function.pkl','wb'))

# %%
pickle.dump(new_PC,open('PCAs.pkl','wb'))

# %%
pickle.dump(sc,open('scalar.pkl','wb'))

# %%
pickle.dump(svm,open('model2.pkl','wb'))

# %%
pickle.dump(new_PC,open('PCAs2.pkl','wb'))

# %%
pickle.dump(sc,open('scalar2.pkl','wb'))
